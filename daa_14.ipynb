# %%
LATIHAN PERTEMUAN 14

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
vertices = range(1, 10)
edges = [(7,2), (2,3), (7,4), (7,3), (7,5), (1,6), (1,7), (2,8), (2,9)]

# %%
G = nx.Graph()

# %%
G.add_nodes_from(vertices)
G.add_edges_from(edges)
pos=nx.spring_layout(G)

# %%
import networkx as nx
import matplotlib.pyplot as plt

vertices = range(1, 10)
edges = [(7,2), (2,3), (7,4), (7,3), (7,5), (1,6), (1,7), (2,8), (2,9)]

G = nx.Graph()
G.add_nodes_from(vertices)
G.add_edges_from(edges)
pos = nx.spring_layout(G)

not_fraud = [1, 4, 3, 8, 9]
fraud = [2, 5, 6, 7]

nx.draw_networkx_nodes(G, pos, nodelist=not_fraud, node_color='g', node_size=1300)
nx.draw_networkx_nodes(G, pos, nodelist=fraud, node_color='r', node_size=1300)
nx.draw_networkx_edges(G, pos, edges, width=3, alpha=0.5, edge_color='b')

labels = {}
labels[1] = '1 NF'
labels[2] = '2 F'
labels[3] = '3 NF'
labels[4] = '4 NF'
labels[5] = '5 F'
labels[6] = '6 F'
labels[7] = '7 F'
labels[8] = '8 NF'
labels[9] = '9 NF'

def calculate_dos(node):
    dos = 0
    for neighbor in G.neighbors(node):
        if labels[neighbor] != labels[node]:
            dos += 1
    return dos

dos_values = {node: calculate_dos(node) for node in G.nodes()}
total_edges = len(edges)
labels_dos = {node: f'{labels[node]}\nDOS={round(dos_values[node]/total_edges, 2)}' for node in G.nodes()}

nx.draw_networkx_labels(G, pos, labels_dos, font_size=10)
plt.axis('off')
plt.show()

# %%
G = nx.Graph()
vertices = range(1, 10)
edges = [(7, 2), (2, 3), (7, 4), (4, 5), (7, 3), (7, 5), (1, 6), (1, 7), (2, 8), (2, 9)]
G.add_nodes_from(vertices)
G.add_edges_from(edges)

degree_values = dict(G.degree())

dos_values = {node: degree for node, degree in degree_values.items()}

print("DOS values:")
for node, dos in dos_values.items():
    print(f"{node}: {dos}")

max_degree = max(degree_values.values())

normalized_dos_values = {node: round((degree / max_degree) * 9, 2) for node, degree in degree_values.items()}

print("\nNormalized DOS values:")
for node, normalized_dos in normalized_dos_values.items():
    print(f"{node}: {normalized_dos}")
# Out:
# DOS values:
# 1: 2
# 2: 4
# 3: 2
# 4: 2
# 5: 2
# 6: 1
# 7: 5
# 8: 1
# 9: 1
#
# Normalized DOS values:
# 1: 3.6
# 2: 7.2
# 3: 3.6
# 4: 3.6
# 5: 3.6
# 6: 1.8
# 7: 9.0
# 8: 1.8
# 9: 1.8

# %%
import networkx as nx
import matplotlib.pyplot as plt

vertices = range(1, 11)
edges = [(1, 2), (1, 7), (2, 3), (2, 7), (3, 4), (3, 6), (5, 6), (6, 7), (7, 8), (7, 10), (8, 9), (8, 10)]

G = nx.Graph()
G.add_nodes_from(vertices)
G.add_edges_from(edges)
pos = nx.spring_layout(G)

not_fraud = [2, 3, 6, 8, 9]
fraud = [1, 4, 5, 7, 10]

nx.draw_networkx_nodes(G, pos, nodelist=not_fraud, node_color='g', node_size=1300)
nx.draw_networkx_nodes(G, pos, nodelist=fraud, node_color='r', node_size=1300)
nx.draw_networkx_edges(G, pos, edges, width=3, alpha=0.5, edge_color='b')

labels = {}
labels[1] = '1\nF'
labels[2] = '2\nNF'
labels[3] = '3\nNF'
labels[4] = '4\nF'
labels[5] = '5\nF'
labels[6] = '6\nNF'
labels[7] = '7\nF'
labels[8] = '8\nNF'
labels[9] = '9\nNF'
labels[10] = '10\nF'

nx.draw_networkx_labels(G, pos, labels, font_size=10)
plt.axis('off')
plt.title('LATIHAN 1')
plt.show()

# %%
vertices = range(1, 14)
edges = [
    (1, 2), (1, 3), (2, 3), (2, 12), (3, 4), (3, 5), (3, 6), (3, 11),
    (4, 5), (4, 7), (5, 6), (5, 7), (5, 8), (6, 9), (7, 8), (8, 9),
    (10, 11), (11, 12), (11, 13), (12, 13)
]

G = nx.Graph()
G.add_nodes_from(vertices)
G.add_edges_from(edges)
pos = nx.spring_layout(G)

not_fraud = [4, 5, 6, 7, 8, 9, 13]
fraud = [1, 2, 3, 10, 11, 12]

nx.draw_networkx_nodes(G, pos, nodelist=not_fraud, node_color='g', node_size=1300)
nx.draw_networkx_nodes(G, pos, nodelist=fraud, node_color='r', node_size=1300)
nx.draw_networkx_edges(G, pos, edges, width=3, alpha=0.5, edge_color='b')

labels = {}
labels[1] = '1\nF'
labels[2] = '2\nF'
labels[3] = '3\nF'
labels[4] = '4\nNF'
labels[5] = '5\nNF'
labels[6] = '6\nNF'
labels[7] = '7\nNF'
labels[8] = '8\nNF'
labels[9] = '9\nNF'
labels[10] = '10\nF'
labels[11] = '11\nF'
labels[12] = '12\nF'
labels[13] = '13\nNF'

nx.draw_networkx_labels(G, pos, labels, font_size=10)
plt.axis('off')
plt.title('LATIHAN 2')
plt.show()
