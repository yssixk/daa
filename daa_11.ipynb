# %%
graph = {"a" : ["b", "c"],
         "b" : ["a", "d"],
         "c" : [ "a", "d"],
         "d" : ["e"],
         "e" : ["d"]}

print(graph)
# Out:
# {'a': ['b', 'c'], 'b': ['a', 'd'], 'c': ['a', 'd'], 'd': ['e'], 'e': ['d']}

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Create a graph
G = nx.Graph()

nodes = ['T', 'U', 'V', 'W', 'X', 'Z', 'S']
G.add_nodes_from(nodes)

edges = [('T', 'U'), ('U', 'V'), ('T', 'W'), ('W', 'X'), ('X', 'Z'), ('Z', 'S')]
G.add_edges_from(edges)

# Draw the graph
plt.figure(figsize=(8, 6))
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_size=3000, node_color='lightblue', font_size=16, font_weight='bold', edge_color='gray')
plt.title("Graph Visualization", fontsize=18)
plt.show()

# %%
G2 = nx.Graph()

# Add nodes
nodes2 = ['r', 'o', 'm', 'l', 'p', 'n']
G2.add_nodes_from(nodes2)

edges2 = [('r', 'o'), ('o', 'm'), ('r', 'l'), ('l', 'p'), ('p', 'n')]
G2.add_edges_from(edges2)

# Draw the graph
plt.figure(figsize=(8, 6))
pos2 = nx.spring_layout(G2)
nx.draw(G2, pos2, with_labels=True, node_size=3000, node_color='lightgreen', font_size=16, font_weight='bold', edge_color='gray')
plt.title("Graph Visualization", fontsize=18)
plt.show()

# %%
class graph:
  def __init__(self, gdict = None):
    if gdict is None:
      gdict = []
    self.gdict = gdict

  def gerVertices(self):
    return list(self.gdict.keys())

graph_elements = {"a" : ["b", "c"],
         "b" : ["a", "d"],
         "c" : [ "a", "d"],
         "d" : ["e"],
         "e" : ["d"]}

g = graph(graph_elements)

print(g.gerVertices())
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
graph = {
    "T": ["U"],
    "U": ["T", "V"],
    "V": ["U"]
}

print("Elemen simpul dalam graph T-U-V:")
for node in graph.keys():
    print(node)
# Out:
# Elemen simpul dalam graph T-U-V:
# T
# U
# V

# %%
graph = {
    "R": ["O"],
    "O": ["R", "M"],
    "M": ["O"]
}

print("Elemen simpul dalam graph ROM:")
for node in graph:
    print(node)
# Out:
# Elemen simpul dalam graph ROM:
# R
# O
# M

# %%
class graph:
  def __init__(self, gdict = None):
    if gdict is None:
      gdict = []
    self.gdict = gdict

  def edges(self):
    return self.findedges()

  def findedges(self):
    edgename = []
    for vrtx in self.gdict:
      for nxtvrtx in self.gdict[vrtx]:
        if {nxtvrtx, vrtx} not in edgename:
          edgename.append({vrtx, nxtvrtx})
    return edgename

graph_elements = {"a" : ["b", "c"],
         "b" : ["a", "d"],
         "c" : [ "a", "d"],
         "d" : ["e"],
         "e" : ["d"]}

g = graph(graph_elements)

print(g.edges())
# Out:
# [{'b', 'a'}, {'c', 'a'}, {'d', 'b'}, {'d', 'c'}, {'d', 'e'}]

# %%
# Display nodes (simpul)
nodes_TUV = G.nodes()
print("Elemen Simpul pada Graph TUV:", nodes_TUV)

# Display edges
edges_TUV = G.edges()
print("Edge pada Graph TUV:", edges_TUV)
# Out:
# Elemen Simpul pada Graph TUV: ['T', 'U', 'V', 'W', 'X', 'Z', 'S']
# Edge pada Graph TUV: [('T', 'U'), ('T', 'W'), ('U', 'V'), ('W', 'X'), ('X', 'Z'), ('Z', 'S')]

# %%
# Display edges
edges_ROM = G2.edges()
print("Edge pada Graph ROM:", edges_ROM)
# Out:
# Edge pada Graph ROM: [('r', 'o'), ('r', 'l'), ('o', 'm'), ('l', 'p'), ('p', 'n')]

# %%
class graph:
  def __init__(self, gdict = None):
    if gdict is None:
      gdict = []
    self.gdict = gdict

  def getVertices(self):
    return list(self.gdict.keys())

  def addVertex(self, vrtx):
    if vrtx not in self.gdict:
      self.gdict[vrtx] = []

graph_elements = {"a" : ["b", "c"],
         "b" : ["a", "d"],
         "c" : [ "a", "d"],
         "d" : ["e"],
         "e" : ["d"]}

g = graph(graph_elements)

g.addVertex("f")

print(g.getVertices())
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
G.add_node('R')

G.add_edge('R', 'T')

plt.figure(figsize=(8, 6))
pos_TUV_updated = nx.spring_layout(G)
nx.draw(G, pos_TUV_updated, with_labels=True, node_size=3000, node_color='lightblue', font_size=16, font_weight='bold', edge_color='gray')
plt.title("Updated Graph Visualization (with 'R')", fontsize=18)
plt.show()

updated_nodes_TUV = G.nodes()
updated_edges_TUV = G.edges()

updated_nodes_TUV, updated_edges_TUV
# Out:
# (NodeView(('T', 'U', 'V', 'W', 'X', 'Z', 'S', 'R')),
#  EdgeView([('T', 'U'), ('T', 'W'), ('T', 'R'), ('U', 'V'), ('W', 'X'), ('X', 'Z'), ('Z', 'S')]))

# %%
G2.add_node('K')
G2.add_node('J')

G2.add_edge('K', 'l')
G2.add_edge('J', 'p')

plt.figure(figsize=(8, 6))
pos_ROM_updated = nx.spring_layout(G2)
nx.draw(G2, pos_ROM_updated, with_labels=True, node_size=3000, node_color='lightgreen', font_size=16, font_weight='bold', edge_color='gray')
plt.title("Updated Graph Visualization (with 'K' and 'J')", fontsize=18)
plt.show()

updated_nodes_ROM = G2.nodes()
updated_edges_ROM = G2.edges()

updated_nodes_ROM, updated_edges_ROM
# Out:
# (NodeView(('r', 'o', 'm', 'l', 'p', 'n', 'K', 'J')),
#  EdgeView([('r', 'o'), ('r', 'l'), ('o', 'm'), ('l', 'p'), ('l', 'K'), ('p', 'n'), ('p', 'J')]))

# %%
class graph:

  def __init__(self, gdict = None):
    if gdict is None:
      gdict = []
    self.gdict = gdict

  def edges(self):
    return self.findedges()

  def AddEdge(self, edge):
    edge = set(edge)
    (vrtx1, vrtx2) = tuple(edge)
    if vrtx1 in self.gdict:
      self.gdict[vrtx1].append(vrtx2)
    else:
      self.gdict[vrtx1] = [vrtx2]

  def findedges(self):
    edgename = []
    for vrtx in self.gdict:
      for nxtvrtx in self.gdict[vrtx]:
        edgename.append({vrtx, nxtvrtx})
    return edgename

# %%
graph_elements = {"a" : ["b", "c"],
         "b" : ["a", "d"],
         "c" : [ "a", "d"],
         "d" : ["e"],
         "e" : ["d"]}

g = graph(graph_elements)
g.AddEdge({'a', 'e'})
g.AddEdge({'a', 'c'})
print(g.edges())
# Out:
# [{'b', 'a'}, {'c', 'a'}, {'b', 'a'}, {'d', 'b'}, {'c', 'a'}, {'d', 'c'}, {'c', 'a'}, {'d', 'e'}, {'d', 'e'}, {'e', 'a'}]

# %%
G.add_edge('T', 'Z')
G.add_edge('V', 'S')

# Draw updated graph
plt.figure(figsize=(8, 6))
pos_updated = nx.spring_layout(G)
nx.draw(G, pos_updated, with_labels=True, node_size=3000, node_color='lightblue',
        font_size=16, font_weight='bold', edge_color='gray')
plt.title("Updated Graph Visualization (Edges T-Z & V-S Added)", fontsize=18)
plt.show()

# Show updated edges
G.edges()
# Out:
# EdgeView([('T', 'U'), ('T', 'W'), ('T', 'R'), ('T', 'Z'), ('U', 'V'), ('V', 'S'), ('W', 'X'), ('X', 'Z'), ('Z', 'S')])

# %%
G2.add_edge('r', 'K')
G2.add_edge('m', 'J')

# Draw updated graph
plt.figure(figsize=(8, 6))
pos_updated_rom = nx.spring_layout(G2)
nx.draw(G2, pos_updated_rom, with_labels=True, node_size=3000, node_color='lightgreen',
        font_size=16, font_weight='bold', edge_color='gray')
plt.title("Updated Graph Visualization (Edges r-K & m-J Added)", fontsize=18)
plt.show()

# Show updated edges
G2.edges()
# Out:
# EdgeView([('r', 'o'), ('r', 'l'), ('r', 'K'), ('o', 'm'), ('m', 'J'), ('l', 'p'), ('l', 'K'), ('p', 'n'), ('p', 'J')])
